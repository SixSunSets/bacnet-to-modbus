# %%
import pandas as pd
excel_path = 'C:/Users/User/Desktop/bacnet-to-modbus/Lista_de_Registros.xlsx'
df = pd.read_excel(excel_path)
df
# Out:
#     ID            IP  Address Nombre equipo Marca equipo         Sede equipo  \
# 0    1  10.84.67.185        1         AC_01           LG  Open Plaza Angamos
# 1    1  10.84.67.185        1         AC_01           LG  Open Plaza Angamos
# 2    1  10.84.67.185        1         AC_01           LG  Open Plaza Angamos
# 3    1  10.84.67.185        1         AC_01           LG  Open Plaza Angamos
# 4    1  10.84.67.185        1         AC_01           LG  Open Plaza Angamos
# ..  ..           ...      ...           ...          ...                 ...
# 85  18  10.84.67.185       30         AC_30           LG  Open Plaza Angamos
# 86  18  10.84.67.185       30         AC_30           LG  Open Plaza Angamos
# 87  18  10.84.67.185       30         AC_30           LG  Open Plaza Angamos
# 88  18  10.84.67.185       30         AC_30           LG  Open Plaza Angamos
# 89  18  10.84.67.185       30         AC_30           LG  Open Plaza Angamos
#
#    Register number  Register type
# ...
